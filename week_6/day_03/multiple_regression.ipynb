# %%
# 3x1 + 2x2 + 4x3 + 5

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
# # Function to create random list 
# def randomList(x):
#     rand_list = []
#     x = 5
#     for i in range(x):
#         rand_list.append(random.randint(1,10))
#     return rand_list


# # Calling randomList function to create random list for x1,x2,x3
# x1 = randomList(6)
# x2 = randomList(6)
# x3 = randomList(6)

# y = 3*x1+2*x2+4*x3

# print(y)

# %%
x1 = np.random.randint(1,10,5)
x2 = np.random.randint(1,10,5)
x3 = np.random.randint(1,10,5)


y = 3*x1+2*x2+4*x3

# %%
plt.plot(x1,x2,x3,y, marker = 'o')
plt.show()
