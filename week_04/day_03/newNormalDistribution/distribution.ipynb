# %%
import pandas as pd

# %%
dataframe = pd.read_csv('healthanxiety_dataset.csv')
dataframe.head()
# Out:
#        subreddit           author      date  \
# 0  healthanxiety         Nomis176  1/1/2018
# 1  healthanxiety  psychstudent317  1/1/2018
# 2  healthanxiety        bulk_barn  1/1/2018
# 3  healthanxiety    AutoModerator  1/1/2018
# 4  healthanxiety    parthkhurana7  1/1/2018
#
#                                                 post  \
# 0  Final doctor appointment tomorrow, tired of co...
# 1  Anyone have bone or muscle pain that was stres...
# 2  Listening to your body? I'm curious how those ...
# 3  Weekly /r/HealthAnxiety Challenge - Exercise A...
# 4  This is killing me So i had a bacterial stomac...
#
#    automated_readability_index  coleman_liau_index  \
# 0                     9.137909            7.282428
# 1                     4.399892            7.131386
# 2                     3.590660            4.930895
# 3                     4.515682            7.033342
# 4                     3.034388            5.356252
#
# ...

# %%
df = dataframe.sample(30)
df.head()
# Out:
#           subreddit              author       date  \
# 718   healthanxiety        Isabella2424   4/9/2018
# 521   healthanxiety      captaincupkirk  3/13/2018
# 1443  healthanxiety     the_sluttysloth  2/27/2019
# 1735  healthanxiety  todaythrowawayokay  3/29/2019
# 1090  healthanxiety     fuzzy_wuzzy_was  1/24/2019
#
#                                                    post  \
# 718   Started with Ectopic beats; now I feel like I’...
# 521   Swollen lymph nodes (for years) driving me up ...
# 1443  Uneven bones I have a chest bone that sticks o...
# 1735  Selling post-cancer anxiety advice I had cance...
# 1090  Stomach problems for 1 month Hi guys, me again...
#
#       automated_readability_index  coleman_liau_index  \
# 718                      4.151389            6.178525
# 521                      3.868677            5.245352
# 1443                     5.236711            4.072480
# 1735                     9.426757            6.950905
# ...

# %%
df.shape
# Out:
# (30, 350)
